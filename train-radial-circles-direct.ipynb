# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import datetime
import numpy as np
import torch
import torch.nn.functional as F

torch.autograd.set_detect_anomaly(True)
# torch.set_default_dtype(torch.float32)

import mediapy as mpy
from tqdm.auto import tqdm
from IPython.display import clear_output, display
import matplotlib.pyplot as plt
import wandb

from nca_model import NCAModel, SimpleNCA
from pool import NCAPool
from utils import nca_out_to_vids, tonp, save_model, load_latest_model, nca_cmap
from data import MNISTPatternGenerator, MNISTPatternPool, generate_radial_circles_pattern

# %%
os.environ["WANDB_NOTEBOOK_NAME"] = "./train.ipynb"

# %%
device = "cuda"
num_classes = 10
channs = 16
bs = 16
S = 80
lr = 0.0008
pool_size = 64
pool_replacement = 0.8

# %%
# nca = NCAModel(channel_n=channs, device=device)
nca = SimpleNCA(channs).to(device)

# %%
inp = torch.rand(5, channs, S, S).to(device)
out = nca(inp, steps=50)
len(out), out[0].shape
# Out:
# (51, torch.Size([5, 16, 80, 80]))

# %%
nca_out_to_vids(out)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>

# %%
pattern = generate_radial_circles_pattern(S, num_classes)
gen = MNISTPatternGenerator(
    is_train=True, channs=channs, bs=bs, pattern=pattern
)

# %%
pool = MNISTPatternPool(
    is_train=True, channs=channs, size=S, pool_size=pool_size, pattern=pattern
)

# %%
sample = pool.sample(bs=bs)

# %%
mpy.show_image(gen.pattern, cmap="viridis", width=150)
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %%
batch = next(gen)

# %%
mpy.show_images(batch["inp"][:8,0], cmap="viridis", width=100, columns=8)
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %%
mpy.show_images(batch["out"][:8], cmap="viridis", width=100, columns=8)
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td></tr></table>

# %%
# nca = NCAModel(channel_n=channs, device=device)
nca = SimpleNCA(channs).to(device)

# %%
import torch.nn as nn

clf = nn.Sequential(
    nn.Linear(6400, 10),
).to(device)

# %%
pattern = generate_radial_circles_pattern(S, num_classes)
# train_gen = MNISTPatternGenerator(
#     is_train=True, channs=channs, bs=bs, pattern=pattern
# )
train_gen = MNISTPatternPool(
    is_train=True, channs=channs, pattern=pattern, pool_size=pool_size, size=S,
    replacement=pool_replacement,
)
test_gen = MNISTPatternGenerator(
    is_train=False, channs=channs, bs=8, pattern=pattern
)

optim = torch.optim.Adam([*nca.parameters(), *clf.parameters()], lr=lr)
history = []

# %%
run = wandb.init(
    project="nca-classifier",
    name="nca-80-direct",
    save_code=True,
)
_ = run.log_code(
    "./",
    include_fn=lambda path: path.endswith(".py") or path.endswith(".ipynb"),
)
# Out:
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find ./train.ipynb.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ichko to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/home/iz/workspace/nca/nca_clf/wandb/run-20250503_233807-mrsrefwc</code>
# Syncing run <strong><a href='https://wandb.ai/ichko/nca-classifier/runs/mrsrefwc' target="_blank">nca-80-direct</a></strong> to <a href='https://wandb.ai/ichko/nca-classifier' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ichko/nca-classifier' target="_blank">https://wandb.ai/ichko/nca-classifier</a>
#  View run at <a href='https://wandb.ai/ichko/nca-classifier/runs/mrsrefwc' target="_blank">https://wandb.ai/ichko/nca-classifier/runs/mrsrefwc</a>

# %%
pbar = tqdm(range(150_000))

for i in pbar:
#     batch = next(train_gen)
    sample = train_gen.sample(bs=bs)
    batch = sample.batch
    inp, out_gt = batch["inp"], batch["out"]
    out_gt = out_gt.to(device)

    steps = np.random.randint(30, 35)
    out_pred = nca(inp.to(device), steps=steps)
    last_step = out_pred[-1]
    last_frame = last_step[:, 0]

    flat_frame = last_frame.view(bs, -1)
    logits = clf(flat_frame)
    
#     logits = torch.stack([
#         last_frame * (pattern.to(device) == c).float().unsqueeze(0)
#         for c in range(1, num_classes + 1)
#     ]).mean(axis=[2, 3]).T

#     loss = F.mse_loss(last_frame, out_gt)
    losses = F.cross_entropy(logits, batch["label"].to(device), reduction="none")
    loss = losses.mean()
    train_gen.update(sample, last_step, losses)


    optim.zero_grad()
    loss.backward()
    optim.step()

    pbar.set_description(f"Loss: {loss:.10f}")
    run.log({"loss": loss.item()})

    history.append(loss.item())

    if i % 150 == 0:
        clear_output()
        display(pbar.container)
        
        plt.plot(history)
        plt.yscale("log")
        plt.show()
        
        with torch.inference_mode():
            out_pred = nca(inp.to(device), steps=50)
            nca_out_to_vids(out_pred, columns=8)

            run.log({"train_example": [
                wandb.Video(v, fps=20) for v in nca_cmap(out_pred)
            ]})
# Out:
#   0%|          | 0/150000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[27], line 30
#      26 train_gen.update(sample, last_step, losses)
#      29 optim.zero_grad()
# ---> 30 loss.backward()
#      31 optim.step()
#      33 pbar.set_description(f"Loss: {loss:.10f}")
#
# File ~/.cache/pypoetry/virtualenvs/nca-ar8j7Liq-py3.10/lib/python3.10/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/.cache/pypoetry/virtualenvs/nca-ar8j7Liq-py3.10/lib/python3.10/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# RuntimeError: Function 'LogSoftmaxBackward0' returned nan values in its 0th output.

# %%
save_path = save_model(nca, ".checkpoints/nca-{now}.pkl")
wandb.save(save_path)
save_path

# %%
run.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁▁▁▁▁▁▁▇▁▁▄█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃▃▄▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>3.39298</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">nca-80-direct</strong> at: <a href='https://wandb.ai/ichko/nca-classifier/runs/mrsrefwc' target="_blank">https://wandb.ai/ichko/nca-classifier/runs/mrsrefwc</a><br> View project at: <a href='https://wandb.ai/ichko/nca-classifier' target="_blank">https://wandb.ai/ichko/nca-classifier</a><br>Synced 5 W&B file(s), 43 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250503_233807-mrsrefwc/logs</code>

# %%
out_pred.shape
# Out:
# torch.Size([501, 8, 16, 80, 80])

# %%
with torch.no_grad():
    batch = next(test_gen)
    inp, out_gt = batch["inp"], batch["out"]
    out_pred = nca(inp.to(device), steps=500)
    nca_out_to_vids(out_pred, columns=8)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="border:1px solid black; image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>

# %%
# nca_loaded = load_latest_model(".checkpoints/")
