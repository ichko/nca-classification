# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import datetime
import numpy as np
import torch
import torch.nn.functional as F

torch.autograd.set_detect_anomaly(True)
# torch.set_default_dtype(torch.float32)

import mediapy as mpy
from tqdm.auto import tqdm
from IPython.display import clear_output, display
import matplotlib.pyplot as plt
import wandb

from nca_model import SimpleNCA
from utils import nca_out_to_vids, tonp, save_model, load_latest_model, nca_cmap, pad_to, nca_clamp
from data import (
    MNISTPatternGenerator,
    MNISTPatternPool,
    generate_radial_circles_pattern,
    generate_canonical_mnist_digits,
)
# Out:
# WARNING: CPU random generator seem to be failing, disabling hardware random number generation
# WARNING: RDRND generated: 0xffffffff 0xffffffff 0xffffffff 0xffffffff

# %%
device = "cuda"
num_classes = 10
channs = 16
bs = 16
S = 80
lr = 0.0008
pool_size = 64
pool_replacement = 1

# %%
from torchvision.datasets.cifar import CIFAR10
ds = CIFAR10("/home/iz/.cache/", download=True)
# Out:
# Files already downloaded and verified

# %%
ds[0][0].resize((128, 128))
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
nca = SimpleNCA(channs, alive_mask=False).to(device)

# %%
inp = torch.rand(5, channs, S, S).to(device)
out = nca(inp, steps=50)
len(out), out[0].shape
# Out:
# (51, torch.Size([5, 16, 80, 80]))

# %%
nca_out_to_vids(out, out_channs=3)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>

# %%
pattern = generate_radial_circles_pattern(S, num_classes)
pool = MNISTPatternPool(
    is_train=True, channs=channs, size=S, pool_size=pool_size, pattern=pattern,
    replacement=pool_replacement, dataset_cls=CIFAR10, out_channs=3
)
sample = pool.sample(bs=bs)
inp = sample.batch["inp"][:, :3]
out = sample.batch["out"]
# Out:
# Files already downloaded and verified

# %%
mpy.show_images(inp.permute(0, 2, 3, 1)[:8], cmap="viridis", width=100)
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %%
mpy.show_images(out.permute(0, 2, 3, 1)[:8], cmap="viridis", width=100)
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td><td style="padding:1px;"><img width="100" height="100" style="image-rendering:pixelated; object-fit:cover;" src="..."/></td></tr></table>

# %%
nca = SimpleNCA(channs, alive_mask=False).to(device)

# %%
train_gen = MNISTPatternPool(
    is_train=True, channs=channs, size=S, pool_size=pool_size, pattern=pattern,
    replacement=pool_replacement, dataset_cls=CIFAR10, out_channs=3
)
# Out:
# Files already downloaded and verified

# %%
# train_gen = MNISTPatternPool(
#     is_train=True, channs=channs, size=S, pool_size=pool_size, pattern=pattern,
#     replacement=pool_replacement, dataset_cls=CIFAR10, out_channs=3
# )
train_gen = MNISTPatternGenerator(
    is_train=True, channs=channs, pattern=pattern,
    dataset_cls=CIFAR10, out_channs=3, bs=bs
)

optim = torch.optim.Adam(nca.parameters(), lr=lr)
history = []
# Out:
# Files already downloaded and verified

# %%
os.environ["WANDB_NOTEBOOK_NAME"] = "./train.ipynb"

experiment_name = "nca-80-radial-cifar10"

run = wandb.init(
    project="nca-classifier",
    name=experiment_name,
    save_code=True,
)
_ = run.log_code(
    "./",
    include_fn=lambda path: path.endswith(".py") or path.endswith(".ipynb"),
)
# Out:
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find ./train.ipynb.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ichko to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/home/iz/workspace/nca/nca_clf/wandb/run-20250506_001127-9mk7ax51</code>
# Syncing run <strong><a href='https://wandb.ai/ichko/nca-classifier/runs/9mk7ax51' target="_blank">nca-80-radial-cifar10</a></strong> to <a href='https://wandb.ai/ichko/nca-classifier' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ichko/nca-classifier' target="_blank">https://wandb.ai/ichko/nca-classifier</a>
#  View run at <a href='https://wandb.ai/ichko/nca-classifier/runs/9mk7ax51' target="_blank">https://wandb.ai/ichko/nca-classifier/runs/9mk7ax51</a>

# %%
pbar = tqdm(range(100_000))

for i in pbar:
#     sample = train_gen.sample(bs)
#     inp, out_gt = sample.batch["inp"], sample.batch["out"]
    batch = next(train_gen)
    inp, out_gt = batch["inp"], batch["out"]
    out_gt = out_gt.to(device)

    steps = np.random.randint(50, 80)
    out_pred = nca(inp.to(device), steps=steps)
    last_step = out_pred[-1]
    last_frame = last_step[:, :3]

    losses = F.mse_loss(last_frame, out_gt, reduction="none")
    losses = losses.reshape(bs, -1).mean(axis=1)
    loss = losses.mean()

#     train_gen.update(sample, last_step, losses)

    optim.zero_grad()
    loss.backward()
    optim.step()

    pbar.set_description(f"Loss: {loss:.10f}")
    run.log({"loss": loss.item()})

    history.append(loss.item())

    if i % 250 == 0:
        clear_output()
        display(pbar.container)
        
        plt.plot(history)
        plt.yscale("log")
        plt.show()
        
        save_model(nca, experiment_name, i)
        
        with torch.inference_mode():
            out_pred = nca(inp.to(device), steps=50)
            nca_out_to_vids(out_pred, columns=8, out_channs=3)

            run.log({"train_example": [
                wandb.Video(nca_clamp(v), fps=20) for v in out_pred.swapaxes(0, 1).clamp(0, 1)
            ]})
# Out:
# Loss: 0.0284484848:  49%|####9     | 49250/100000 [10:35:45<11:45:07,  1.20it/s]
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table><table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td><td style="padding:1px;"><img width="150" height="150" style="image-rendering:pixelated; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>
# KeyboardInterrupt

# %%
save_path = save_model(nca, experiment_name, i)
# wandb.save(save_path)
save_path
# Out:
# '.checkpoints/nca-80-radial-cifar10/nca-49403-[2025-05-06-11-20-25].pkl'

# %%
run.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▇▅▆▃▆▂▅▂▄▁▃▂▄▆▂▂▁▃▆▆▇▅▃▃▅▂▅▂▄▁▄▃▅██████▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>0.02804</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">nca-80-radial-cifar10</strong> at: <a href='https://wandb.ai/ichko/nca-classifier/runs/9mk7ax51' target="_blank">https://wandb.ai/ichko/nca-classifier/runs/9mk7ax51</a><br> View project at: <a href='https://wandb.ai/ichko/nca-classifier' target="_blank">https://wandb.ai/ichko/nca-classifier</a><br>Synced 5 W&B file(s), 3376 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250506_001127-9mk7ax51/logs</code>

# %% [markdown]
# ## Explore outputs

# %%
nca_loaded = torch.load(".checkpoints/nca-80-canon-alive-mask/nca-46453-[2025-05-05-11-33-13].pkl")
nca_loaded = nca_loaded.to(device)

# %%
test_gen = MNISTPatternGenerator(
    is_train=False,
    channs=channs,
    bs=1,
    pattern=canonical_mnist_digits,
    loop_forever=False,
    shuffle=False,
)

# %%
res = []
with torch.inference_mode():
    for batch in tqdm(test_gen):
        out_pred = nca_loaded(batch["inp"].to(device), steps=50)

        rollout = tonp(out_pred[:, 0, 0])

        last_step = out_pred[-1]
        last_frame = last_step[:, 0]
        loss = F.mse_loss(last_frame, batch["out"].to(device))

        res.append({
#             "rollout": rollout,
            "label": tonp(batch["label"][0]).item(),
            "loss": loss.item(),
        })

# %%
import pandas as pd

# %%
df = pd.DataFrame(res).reset_index()
low_loss = df.sort_values("loss").iloc[:10]
high_loss = df.sort_values("loss").iloc[-10:]
rand_loss = df.sort_values("loss").sample(10)

# %%
grouped = []
for i in range(num_classes):
    item = df.groupby("label").get_group(i).sort_values("loss").iloc[550]
    grouped.append(item.to_dict())

# %%
ids = [int(g["index"]) for g in grouped]

# %%
rollouts = []
with torch.inference_mode():
    for idx in tqdm(ids):
        item = test_gen.ds[idx]
        inp = item["inp"].unsqueeze(0).to(device)
        out_pred = nca_loaded(inp, steps=80)
        rollout = tonp(out_pred[:, 0, 0])
        rollouts.append(rollout)

# %%
for i in [0, 10, 20, 30, -1]:
    mpy.show_images([r[i] for r in rollouts], cmap="viridis", width=50, vmin=0.1, vmax=1)
    
mpy.show_images(
    [r[-1] - np.array(test_gen.pattern[i]) for i, r in enumerate(rollouts)],
    cmap="viridis", width=50, vmin=0, vmax=1,
)

# %%
mpy.show_videos([
    mpy.to_rgb(r, cmap="viridis", vmin=0, vmax=1) for r in rollouts],
    width=120,
    codec="gif",
    fps=25
)

# %%
for c in range(num_classes):
    losses = df[df["label"] == c]["loss"]
    plt.hist(losses, bins=50, alpha=0.5, label=c)
plt.legend()

# %%
frames = []
for i in tqdm(range(num_classes)):
    vs = df.groupby("label").get_group(i).sort_values("loss")
#     print(len(vs))
    item = vs.iloc[[0, 250, 500, 800, -5]]
    it = {k: list(v.values()) for k, v in item.to_dict().items()}

    last_frames = []
    with torch.inference_mode():
        for idx in it["index"]:
            item = test_gen.ds[idx]
            inp = item["inp"].unsqueeze(0).to(device)
            out_pred = nca_loaded(inp, steps=100)
            last_frame = tonp(out_pred[-1, 0, 0])
            first_frame = tonp(out_pred[0, 0, 0])

#             last_frames.append(first_frame)
            last_frames.append(last_frame)

    frames.append(last_frames)

# %%
for i in range(len(frames[0])):
    mpy.show_images([fs[i] for fs in frames], cmap="viridis", width=50)

# %% [markdown]
# ## CLF

# %%
train_gen = MNISTPatternGenerator(
    is_train=True,
    channs=channs,
    bs=1,
    pattern=canonical_mnist_digits,
    loop_forever=False,
    shuffle=False,
)
test_gen = MNISTPatternGenerator(
    is_train=False,
    channs=channs,
    bs=1,
    pattern=canonical_mnist_digits,
    loop_forever=False,
    shuffle=False,
)

# %%
train_res = []
nca_loaded = nca_loaded.eval()

for batch in tqdm(train_gen):
    with torch.inference_mode():
        out_pred = nca_loaded(batch["inp"].to(device), steps=50)

        rollout = tonp(out_pred[:, 0, 0])
        first_frame = rollout[0]
        last_frame = rollout[-1]

#         last_step = out_pred[-1]
#         last_frame = last_step[:, 0]
#         loss = F.mse_loss(last_frame, batch["out"].to(device))

        train_res.append({
            "first_frame": first_frame,
            "last_frame": last_frame,
            "label": tonp(batch["label"][0]).item(),
#             "loss": loss.item(),
        })

# %%
train_df = pd.DataFrame(train_res)
train_df.head()

# %%
test_res = []
for i, batch in enumerate(tqdm(test_gen)):
    with torch.inference_mode():
        out_pred = nca_loaded(batch["inp"].to(device), steps=50)

        rollout = tonp(out_pred[:, 0, 0])
        first_frame = rollout[0]
        last_frame = rollout[-1]

#         last_step = out_pred[-1]
#         last_frame = last_step[:, 0]
#         loss = F.mse_loss(last_frame, batch["out"].to(device))

        test_res.append({
            "first_frame": first_frame,
            "last_frame": last_frame,
            "label": tonp(batch["label"][0]).item(),
#             "loss": loss.item(),
        })

# %%
test_df = pd.DataFrame(test_res)
test_df.head()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
X_train = np.stack(train_df.last_frame.values)
X_train = X_train.reshape(X_train.shape[0], -1)
y_train = train_df.label.values

X_test = np.stack(test_df.last_frame.values)
X_test = X_test.reshape(X_test.shape[0], -1)
y_test = test_df.label.values

# %%
# import gc
# gc.collect()
# torch.cuda.empty_cache()

# %%
lin_model = LogisticRegression(max_iter=300)
lin_model.fit(X_train, y_train)

# %%
lin_model.score(X_train, y_train), lin_model.score(X_test, y_test)

# %%
print(classification_report(y_train, lin_model.predict(X_train)))

# %%
print(classification_report(y_test, lin_model.predict(X_test)))

# %%
mpy.show_images(lin_model.coef_.reshape(10, 32, 32), cmap="viridis", width=100)

# %%
# plt.bar(range(10), lin_model.intercept_)

# %% [markdown]
# ---

# %%
X_train = np.stack(train_df.first_frame.values)
X_train = X_train.reshape(X_train.shape[0], -1)
y_train = train_df.label.values

X_test = np.stack(test_df.first_frame.values)
X_test = X_test.reshape(X_test.shape[0], -1)
y_test = test_df.label.values

# %%
lin_model = LogisticRegression(max_iter=300)
lin_model.fit(X_train, y_train)

# %%
lin_model.score(X_train, y_train), lin_model.score(X_test, y_test)

# %%
print(classification_report(y_train, lin_model.predict(X_train)))

# %%
print(classification_report(y_test, lin_model.predict(X_test)))

# %%
mpy.show_images(lin_model.coef_.reshape(10, 32, 32), cmap="viridis", width=100)
